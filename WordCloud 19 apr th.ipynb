# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
list = ["hello", "how", "are", "you", "hello", "i", "am", "fine"]

# %%
import matplotlib.pyplot as plt

# %%
string = ['hello', 'how', 'are', 'you']

# %%
from wordcloud import WordCloud
import pandas as pd

# %%
with open('news.txt') as f:
    lines = f.readlines

# %%
lines = str(lines)

# %%
lines
# Out:
# '<built-in method readlines of _io.TextIOWrapper object at 0x000001BB6D0BF930>'

# %%
wc = WordCloud(width=800, height=800, background_color = 'white').generate(lines)

# %%
plt.figure(figsize=(12,5))
plt.imshow(wc)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# stream visualization - live data monitoring (eg. stock market, live corona cases, live song listeners, video statistics)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = ['rock', 'pop', 'country', 'folk', 'metal']

# %%
y = [1000, 5000, 500, 250, 2500]

# %%
sns.barplot(x=y,y=x)
# Out:
# <AxesSubplot:>
