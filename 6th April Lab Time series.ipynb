# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
year = [1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
population = [4, 7, 7, 8, 9, 11, 13, 14, 17]
plt.plot(year, population)
plt.xlabel("Year")
plt.ylabel("Population")
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19152/1030746837.py in <module>
#       2 population = [4, 7, 7, 8, 9, 11, 13, 14, 17]
#       3 plt.plot(year, population)
# ----> 4 plt.xlabel("Year")
#       5 plt.ylabel("Population")
#
# TypeError: 'str' object is not callable

# %%
array = ([1, 4, 9, 16, 25, 36, 49, 64, 81])

# %%
sum_x = np.sum(x)

# %%
sum_y = np.sum(y)

# %%
ssum_xy = np.sum
