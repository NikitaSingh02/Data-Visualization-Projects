# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotnine as ggplot

# %%
import warnings
warnings.filterwarnings("ignore") #won't show any warnings during execution

# %%
sns.set(style="white", color_codes = True)

# %%
iris = pd.read_csv("Iris.csv") # DA 3 - Do the same for tips dataset

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris = iris.drop(['Id'], axis = 1)

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris.plot(kind = "scatter", x = "PetalLengthCm", y = "PetalWidthCm")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
iris.plot(kind = "scatter", x = "SepalLengthCm", y = "SepalWidthCm")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.jointplot(x = "SepalLengthCm", y = "SepalWidthCm", data = iris, size = 5)

# %%
sns.FacetGrid(iris, hue = "Species", size = 5)\
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm")\
   .add_legend()

# %%
sns.FacetGrid(iris, hue = "Species", size = 5)\
   .map(plt.scatter, "PetalLengthCm", "PetalWidthCm")\
   .add_legend()

# %%
sns.FacetGrid(iris, hue = "Species", size = 5)\
   .map(plt.scatter, "PetalLengthCm", "SepalLengthCm")\
   .add_legend()

# %%
sns.boxplot(x = "Species", y = "PetalLengthCm", data = iris)
# here all three are separated...which means this species can be separated
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.boxplot(x = "Species", y = "SepalLengthCm", data = iris)
# here all three are separated...which means this species can be separated
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(x = "Species", y = "PetalWidthCm", data = iris)
# here all three are separated...which means this species can be separated
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %%
sns.boxplot(x = "Species", y = "SepalWidthCm", data = iris)
# useless feature all are overlapping...all the data is between 2.5 to 3.6....even if we remove this feature results wont change
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
iris.boxplot(by = "Species", figsize = (12, 6))
# here the data for last graph completely overlaps...therefore the feature used for the last one is useless for distinguishing the 3 classes,,,other 3 graphs are fine... dont overlap that much
# Out:
# array([[<AxesSubplot:title={'center':'PetalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}, xlabel='[Species]'>],
#        [<AxesSubplot:title={'center':'SepalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
# if overlapping is more, we cant use that feature to classify as they will lead to inaccuracy
# we need discriminating features
# if there's overlapping, high correlation - > eliminate that feature
# during experimantation, whatever accuracy u get from the 4 features, u'll get similar accuracy with 3 features

# %%
ax = sns.stripplot(x = "Species", y = "SepalWidthCm", data = iris, jitter = True, edgeColor = "gray")
ax
#ax = sns.boxplot(x = "Species", y = "SepalWidthCm", data = iris)
#ax
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.violinplot(x = "Species", y = "SepalWidthCm", data = iris, size = 6)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
ax = sns.stripplot(x = "Species", y = "SepalWidthCm", data = iris, jitter = True, edgeColor = "gray")
#ax
ax = sns.boxplot(x = "Species", y = "SepalWidthCm", data = iris)
#ax

# %%
ax = sns.boxplot(x = "Species", y = "SepalWidthCm", data = iris)
ax = sns.violinplot(x = "Species", y = "SepalWidthCm", data = iris)

# %%
ax = sns.scatterplot(x = "Species", y = "SepalWidthCm", data = iris)
ax = sns.violinplot(x = "Species", y = "SepalWidthCm", data = iris)
ax
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.FacetGrid(iris, hue = "Species", size = 6)\
   .map(sns.kdeplot, "PetalLengthCm")\
   .add_legend()

# %%
sns.FacetGrid(iris, hue = "Species", size = 6)\
   .map(sns.kdeplot, "PetalWidthCm")\
   .add_legend()

# %%
sns.FacetGrid(iris, hue = "Species", size = 6)\
   .map(sns.kdeplot, "SepalLengthCm")\
   .add_legend()

# %%
sns.FacetGrid(iris, hue = "Species", height = 6)\
   .map(sns.kdeplot, "SepalWidthCm")\
   .add_legend()

# %%
sns.pairplot(iris, hue = "Species", height = 3)

# %%
#conclusion = sepalwidth needs to be removed, sepal length can be removed, other two features are distinguishing

# %%
plt.figure(figsize = (5,5))
sns.pairplot(iris, hue = "Species", height = 3)
plt.show()

# %%
# plot any 5 of the above plots for tips dataset for DA 3
