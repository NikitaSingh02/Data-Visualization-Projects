# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotnine as ggplot

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.set(style="white", color_codes = True)

# %%
tips = pd.read_csv("tips.csv")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
tips.plot(kind = "scatter", x = "tip", y = "sex")
plt.show()
# Conclusion : This parameter is a useful factor.
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
tips.plot(kind = "scatter", x = "tip", y = "smoker")
plt.show()
# Conclusion : This parameter is a useful factor.
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
tips.plot(kind = "scatter", x = "tip", y = "day")
plt.show()
# Conclusion : This parameter is a useful factor.
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
tips.plot(kind = "scatter", x = "tip", y = "time")
plt.show()
# Conclusion : This parameter is a useful factor.
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.jointplot(x = "tip", y = "sex", data = tips, size = 5)

# %%
sns.jointplot(x = "tip", y = "smoker", data = tips, size = 5)

# %%
sns.jointplot(x = "tip", y = "day", data = tips, size = 5)

# %%
sns.jointplot(x = "tip", y = "time", data = tips, size = 5)

# %%
sns.jointplot(x = "tip", y = "size", data = tips, size = 5)

# %%
tips.plot(kind = "scatter", x = "sex", y = "smoker")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
tips.plot(kind = "scatter", x = "day", y = "time")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.FacetGrid(tips, hue = "sex", size = 5)\
   .map(plt.scatter, "tip", "smoker")\
   .add_legend()

# %%
sns.FacetGrid(tips, hue = "sex", size = 5)\
   .map(plt.scatter, "tip", "day")\
   .add_legend()

# %%
sns.FacetGrid(tips, hue = "sex", size = 5)\
   .map(plt.scatter, "tip", "time")\
   .add_legend()

# %%
sns.FacetGrid(tips, hue = "smoker", size = 5)\
   .map(plt.scatter, "tip", "sex")\
   .add_legend()

# %%
sns.FacetGrid(tips, hue = "smoker", size = 5)\
   .map(plt.scatter, "tip", "day")\
   .add_legend()

# %%
sns.FacetGrid(tips, hue = "smoker", size = 5)\
   .map(plt.scatter, "tip", "time")\
   .add_legend()

# %%
sns.FacetGrid(tips, hue = "day", size = 5)\
   .map(plt.scatter, "tip", "sex")\
   .add_legend()

# %%
sns.FacetGrid(tips, hue = "day", size = 5)\
   .map(plt.scatter, "tip", "time")\
   .add_legend()

# %%
sns.boxplot(x = "tip", y = "time", data = tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='time'>

# %%
sns.boxplot(x = "day", y = "tip", data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x = "time", y = "tip", data = tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.boxplot(x = "smoker", y = "tip", data = tips)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %%
sns.boxplot(x = "sex", y = "tip", data = tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
tips.boxplot(by = "time", figsize = (12, 6))
# Out:
# array([[<AxesSubplot:title={'center':'size'}, xlabel='[time]'>,
#         <AxesSubplot:title={'center':'tip'}, xlabel='[time]'>],
#        [<AxesSubplot:title={'center':'total_bill'}, xlabel='[time]'>,
#         <AxesSubplot:>]], dtype=object)

# %%
tips.boxplot(by = "day", figsize = (12, 6))
# Out:
# array([[<AxesSubplot:title={'center':'size'}, xlabel='[day]'>,
#         <AxesSubplot:title={'center':'tip'}, xlabel='[day]'>],
#        [<AxesSubplot:title={'center':'total_bill'}, xlabel='[day]'>,
#         <AxesSubplot:>]], dtype=object)

# %%
tips.boxplot(by = "smoker", figsize = (12, 6))
# Out:
# array([[<AxesSubplot:title={'center':'size'}, xlabel='[smoker]'>,
#         <AxesSubplot:title={'center':'tip'}, xlabel='[smoker]'>],
#        [<AxesSubplot:title={'center':'total_bill'}, xlabel='[smoker]'>,
#         <AxesSubplot:>]], dtype=object)

# %%
tips.boxplot(by = "sex", figsize = (12, 6))
# Out:
# array([[<AxesSubplot:title={'center':'size'}, xlabel='[sex]'>,
#         <AxesSubplot:title={'center':'tip'}, xlabel='[sex]'>],
#        [<AxesSubplot:title={'center':'total_bill'}, xlabel='[sex]'>,
#         <AxesSubplot:>]], dtype=object)

# %%
ax = sns.stripplot(x = "tip", y = "smoker", data = tips, jitter = True, edgeColor = "gray")
ax
# Out:
# <AxesSubplot:xlabel='tip', ylabel='smoker'>

# %%
ax = sns.stripplot(x = "tip", y = "day", data = tips, jitter = True, edgeColor = "gray")
ax
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
ax = sns.stripplot(x = "tip", y = "time", data = tips, jitter = True, edgeColor = "gray")
ax
# Out:
# <AxesSubplot:xlabel='tip', ylabel='time'>

# %%
ax = sns.stripplot(x = "tip", y = "sex", data = tips, jitter = True, edgeColor = "gray")
ax
# Out:
# <AxesSubplot:xlabel='tip', ylabel='sex'>

# %%
sns.violinplot(x = "tip", y = "smoker", data = tips, size = 6)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='smoker'>

# %%
sns.violinplot(x = "tip", y = "smoker", data = tips, size = 6)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='smoker'>

# %%
sns.violinplot(x = "tip", y = "day", data = tips, size = 6)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.violinplot(x = "tip", y = "sex", data = tips, size = 6)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='sex'>

# %%
sns.violinplot(x = "size", y = "tip", data = tips, size = 6)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
ax = sns.stripplot(x = "tip", y = "day", data = tips, jitter = True, edgeColor = "gray")
#ax
ax = sns.boxplot(x = "tip", y = "day", data = tips)
#ax

# %%
ax = sns.stripplot(x = "tip", y = "time", data = tips, jitter = True, edgeColor = "gray")
#ax
ax = sns.boxplot(x = "tip", y = "time", data = tips)
#ax

# %%
ax = sns.stripplot(x = "tip", y = "smoker", data = tips, jitter = True, edgeColor = "gray")
#ax
ax = sns.boxplot(x = "tip", y = "smoker", data = tips)
#ax

# %%
ax = sns.boxplot(x = "tip", y = "smoker", data = tips)
ax = sns.violinplot(x = "tip", y = "smoker", data = tips)

# %%
ax = sns.boxplot(x = "tip", y = "day", data = tips)
ax = sns.violinplot(x = "tip", y = "day", data = tips)

# %%
sns.FacetGrid(tips, hue = "day", size = 6)\
   .map(sns.kdeplot, "tip")\
   .add_legend()

# %%
sns.FacetGrid(tips, hue = "size", size = 6)\
   .map(sns.kdeplot, "tip")\
   .add_legend()

# %%
sns.FacetGrid(tips, hue = "sex", size = 6)\
   .map(sns.kdeplot, "tip")\
   .add_legend()

# %%
sns.FacetGrid(tips, hue = "smoker", size = 6)\
   .map(sns.kdeplot, "tip")\
   .add_legend()

# %%
sns.pairplot(tips, hue = "tip", height = 3)

# %%
sns.pairplot(tips, hue = "day", height = 3)

# %%
sns.pairplot(tips, hue = "time", height = 3)

# %%
sns.pairplot(tips, hue = "sex", height = 3)

# %%
sns.pairplot(tips, hue = "smoker", height = 3)

# %%
sns.pairplot(tips, hue = "size", height = 3)

# %%
sns.pairplot(tips, hue = "total_bill", height = 3)

# %%
#
