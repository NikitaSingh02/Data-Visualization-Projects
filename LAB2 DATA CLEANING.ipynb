# %%
import numpy as np
data = np.array([0.5, 0.7, 2.1, 2.9, 3.2, 3.2, 3.3, 3.7, 4.5, 4.6, 4.8, 5.2, 5.3, 6.7, 8.1])

# %%
data
# Out:
# array([0.5, 0.7, 2.1, 2.9, 3.2, 3.2, 3.3, 3.7, 4.5, 4.6, 4.8, 5.2, 5.3,
#        6.7, 8.1])

# %%
import matplotlib.pyplot as plt
#from matplotlib import pyplot as plt
import pandas as pd
df = pd.DataFrame(data)
df.hist(figsize=(20,5))
df.plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import pandas as pd
df = pd.read_csv('Marketing_Analysis.csv', low_memory = False)
df
# Out:
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# ...                     ...        ...                           ...
# 45208                 45207         51                         60000
# 45209                 45208         71                         55000
# 45210                 45209         72                         55000
# 45211                 45210         57                         20000
# 45212                 45211         37                        120000
#
#       Unnamed: 3                                         Unnamed: 4  \
# 0            NaN  Customer marital status and job with education...
# ...

# %%
df = pd.read_csv('Marketing_Analysis.csv', low_memory = False, skiprows = 2) #as first 2 rows dont have any values we can operate upon

# %%
df.head() #prints only first 5 rows || row indexing in python starts from 0 |||ly df.tail() prints last 5
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
df['jobedu'].apply(lambda x:x.split(",")[0])
# Out:
# 0          management
# 1          technician
# 2        entrepreneur
# 3         blue-collar
# 4             unknown
#              ...
# 45206      technician
# 45207         retired
# 45208         retired
# 45209     blue-collar
# 45210    entrepreneur
# Name: jobedu, Length: 45211, dtype: object

# %%
df['jobedu'].apply(lambda x:x.split(",")[1])
# Out:
# 0         tertiary
# 1        secondary
# 2        secondary
# 3          unknown
# 4          unknown
#            ...
# 45206     tertiary
# 45207      primary
# 45208    secondary
# 45209    secondary
# 45210    secondary
# Name: jobedu, Length: 45211, dtype: object

# %%
df["job"] = df["jobedu"].apply(lambda x:x.split(",")[0])
df["Education"] = df["jobedu"].apply(lambda x:x.split(",")[1])

# %%
df #u can see 2 columns - job & education added to the rightmost part of the table
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
# ...

# %%
df.drop("jobedu") #error as we didnt set axis = 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5752/2306271684.py in <module>
# ----> 1 df.drop("jobedu")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
df.drop("jobedu", axis = 'columns') #if u want to drop only label:axis=0||if u want ot drop entire column:axis=1
#we could also use axis = 'columns' === i m not sure abt this
df.drop("customerid", axis = 1)
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %%
#Count null values in each column
df.isnull().sum() #  ?????why is customerid showing?????
#possible answer could be it only show the most recent operation....not convincing
# Out:
# customerid     0
# age           20
# salary         0
# balance        0
# marital        0
# jobedu         0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# job            0
# Education      0
# dtype: int64

# %%
#remove null values from age
df[~df.age.isnull()]
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
# ...

# %%
df=df[~df.age.isnull()].copy()
df=df[~df.month.isnull()].copy()
df=df[~df.response.isnull()].copy()

# %%
df.shape #to get no of rows and columns
# Out:
# (45111, 21)

# %%
age = df.age

# %%
age
# Out:
# 0        58.0
# 1        44.0
# 2        33.0
# 3        47.0
# 4        33.0
#          ...
# 45206    51.0
# 45207    71.0
# 45208    72.0
# 45209    57.0
# 45210    37.0
# Name: age, Length: 45111, dtype: float64

# %%
age.hist()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns #for histogram
import matplotlib.pyplot as plt #probably for figsize
# %matplotlib inline

# %%
plt.figure(figsize=(12,6))
sns.histplot(age, kde = False, stat = "percent", color = "skyblue", bins=100)  
#u can give stat="probability" it will show prob instead of percent||if u dont write stat at all i twill show count
# Out:
# <AxesSubplot:xlabel='age', ylabel='Percent'>

# %%
plt.figure(figsize=(12,6))
sns.distplot(age, bins=100, hist=False)
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))   #total area of kde plot = 1
sns.kdeplot(age, linewidth = 3) #, bins=100, hist=False)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(age)
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
age.median()
# Out:
# 39.0

# %%
plt.figure(figsize=(12,6))
sns.violinplot(age)
#it is having boxplot inside {the black part}
#the white dot inside is median = 39
# !!!!!!!!!!dont use inner=stick it is stopping all operations!!!!!!!!!
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.violinplot(x=tips["total_bill"])

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x=tips["day"], y=tips["tip"])
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
plt.figure(figsize=(12,6))
sns.violinplot(df["age"], df["salary"])
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='salary'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(df["salary"], df["age"])
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='salary', ylabel='age'>

# %%
plt.figure(figsize=(12,6))
sns.violinplot(df["salary"], df["age"])
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='salary', ylabel='age'>
