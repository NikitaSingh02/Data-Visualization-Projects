# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('University_Placements.csv', low_memory = False)
df
# Out:
#          name of company                                  college name  \
# 0                XORIANT               XAVIER INSTITUTE OF ENGINEERING
# 1                XORIANT  INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT
# 2                XORIANT           VISHWAKARMA INSTITUTE OF TECHNOLOGY
# 3                QUINNOX                 PILLAI COLLEGE OF ENGINEERING
# 4                QUINNOX  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# ..                   ...                                           ...
# 473  ARK TECHNOSOLUTIONS  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# 474             ACCOLITE          K. J. SOMAIYA COLLEGE OF ENGINEERING
# 475             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 476             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 477             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
#
#           region  year   Salary
# 0         MUMBAI  2018   657673
# 1           PUNE  2018   657673
# ...

# %%
grouped_df = df.groupby("name of company")
grouped_lists = grouped_df["college name"].apply(list)
grouped_lists = grouped_lists.reset_index()
print(grouped_lists)
# Out:
#              name of company  \
# 0                  ACCENTURE
# 1                   ACCOLITE
# 2                      ADOBE
# 3                     AMAZON
# 4                     AMDOCS
# ..                       ...
# 117                  XORIANT
# 118                    YAHOO
# 119  ZENITH SYSTEM SOLUTIONS
# 120      ZENSAR TECHNOLOGIES
# 121                    ZYCUS
#
#                                           college name
# 0    [PILLAI COLLEGE OF ENGINEERING, THAKUR COLLEGE...
# 1    [K. J. SOMAIYA COLLEGE OF ENGINEERING, PUNE IN...
# 2    [DWARKADAS J. SANGHVI COLLEGE OF ENGINEERING, ...
# 3    [PILLAI HOC COLLEGE OF ENGINEERING AND TECHNOL...
# 4    [THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY,...
# ..                                                 ...
# 117  [XAVIER INSTITUTE OF ENGINEERING, INDIRA COLLE...
# 118                      [COLLEGE OF ENGINEERING PUNE]
# 119  [PILLAI HOC COLLEGE OF ENGINEERING AND TECHNOL...
# ...

# %%
grouped_dfs = df.groupby("college name")
grouped_listss = grouped_dfs["name of company"].apply(list)
grouped_listss = grouped_listss.reset_index()
print(grouped_listss)
# Out:
#                                          college name  \
# 0   ALAMURI RATNAMALA INSTITUTE OF ENGINEERING & T...
# 1                        ARMY INSTITUTE OF TECHNOLOGY
# 2           BHARATI VIDYAPEETH COLLEGE OF ENGINEERING
# 3                         COLLEGE OF ENGINEERING PUNE
# 4             DHOLE PATIL COLLEGE OF ENGINEERING PUNE
# 5                    DR. D. Y. PATIL VIDYAPEETH, PUNE
# 6         DWARKADAS J. SANGHVI COLLEGE OF ENGINEERING
# 7        INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT
# 8                K. J. SOMAIYA COLLEGE OF ENGINEERING
# 9               LOKMANYA TILAK COLLEGE OF ENGINEERING
# 10                         MIT COLLEGE OF ENGINEERING
# 11                      PILLAI COLLEGE OF ENGINEERING
# 12   PILLAI HOC COLLEGE OF ENGINEERING AND TECHNOLOGY
# 13              PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 14                RAMRAO ADIK INSTITUTE OF TECHNOLOGY
# 15       SHREE RAMCHANDRA COLLEGE OF ENGINEERING,PUNE
# ...

# %%
# Choosing 7 universities from the dataset
f = df.loc[df['college name'].isin(['THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY',
     'THADOMAL SHAHANI ENGINEERING COLLEGE', 'INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT',
     'DWARKADAS J. SANGHVI COLLEGE OF ENGINEERING', 'PUNE INSTITUTE OF COMPUTER TECHNOLOGY',
     'PILLAI COLLEGE OF ENGINEERING', 'MIT COLLEGE OF ENGINEERING'])]
f
# Out:
#          name of company                                  college name  \
# 1                XORIANT  INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT
# 3                QUINNOX                 PILLAI COLLEGE OF ENGINEERING
# 4                QUINNOX  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# 5                QUINNOX          THADOMAL SHAHANI ENGINEERING COLLEGE
# 11               QUINNOX                    MIT COLLEGE OF ENGINEERING
# ..                   ...                                           ...
# 472            AXIS BANK         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 473  ARK TECHNOSOLUTIONS  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# 475             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 476             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 477             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
#
#           region  year   Salary
# 1           PUNE  2018   657673
# 3    NAVI MUMBAI  2018   446973
# ...

# %%
# Choosing 5 companies from the dataset
fin = f.loc[f['name of company'].isin(['INFOSYS', 'MORGAN STANLEY', 'TCS', 'CAPGEMINI', 'AMDOCS'])]
fin
# Out:
#     name of company                                  college name  \
# 59          INFOSYS                 PILLAI COLLEGE OF ENGINEERING
# 60          INFOSYS  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# 61          INFOSYS  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# 63          INFOSYS          THADOMAL SHAHANI ENGINEERING COLLEGE
# 67          INFOSYS   DWARKADAS J. SANGHVI COLLEGE OF ENGINEERING
# 68          INFOSYS   DWARKADAS J. SANGHVI COLLEGE OF ENGINEERING
# 69          INFOSYS   DWARKADAS J. SANGHVI COLLEGE OF ENGINEERING
# 72          INFOSYS  INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT
# 76          INFOSYS                    MIT COLLEGE OF ENGINEERING
# 77          INFOSYS         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 130  MORGAN STANLEY          THADOMAL SHAHANI ENGINEERING COLLEGE
# 134  MORGAN STANLEY   DWARKADAS J. SANGHVI COLLEGE OF ENGINEERING
# 135  MORGAN STANLEY   DWARKADAS J. SANGHVI COLLEGE OF ENGINEERING
# ...

# %%
# Reset index
fin.reset_index(inplace = True, drop = True)
fin
# Out:
#    name of company                                  college name       region  \
# 0          INFOSYS                 PILLAI COLLEGE OF ENGINEERING  NAVI MUMBAI
# 1          INFOSYS  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY       MUMBAI
# 2          INFOSYS  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY       MUMBAI
# 3          INFOSYS          THADOMAL SHAHANI ENGINEERING COLLEGE       MUMBAI
# 4          INFOSYS   DWARKADAS J. SANGHVI COLLEGE OF ENGINEERING       MUMBAI
# 5          INFOSYS   DWARKADAS J. SANGHVI COLLEGE OF ENGINEERING       MUMBAI
# 6          INFOSYS   DWARKADAS J. SANGHVI COLLEGE OF ENGINEERING       MUMBAI
# 7          INFOSYS  INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT         PUNE
# 8          INFOSYS                    MIT COLLEGE OF ENGINEERING         PUNE
# 9          INFOSYS         PUNE INSTITUTE OF COMPUTER TECHNOLOGY         PUNE
# 10  MORGAN STANLEY          THADOMAL SHAHANI ENGINEERING COLLEGE       MUMBAI
# ...

# %%
x = fin['name of company']
y = fin['Salary']
plt.figure(figsize=(12,6))
sns.set_style("whitegrid")
sns.boxplot(x, y, hue = fin["college name"], linewidth=1.5)
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='name of company', ylabel='Salary'>

# %%
plt.figure(figsize=(12,6))
sns.violinplot(x, y, hue = fin["college name"], data = fin, linewidth=1.5)
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='name of company', ylabel='Salary'>

# %%
plt.figure(figsize=(22,10))
sns.catplot(x, y, data = fin, )
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44788/1105371785.py in <module>
#       1 plt.figure(figsize=(22,10))
# ----> 2 sns.catplot(x, y, data = fin, hue=fin["college name"])
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.catplot(x, y, hue="college name",
               data=fin, kind="violin")
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44788/975241820.py in <module>
# ----> 1 sns.catplot(x, y, hue="college name",
#       2                data=fin, kind="violin")
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(18,10))
sns.barplot(x, y, data=fin, hue="college name")
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='name of company', ylabel='Salary'>

# %%
plt.figure(figsize=(18,10))
sns.catplot(x, y, hue="college name", kind="swarm", data=fin)
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Nikita\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...
